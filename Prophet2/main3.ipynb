# %%
# Python
import pandas as pd
import numpy as np
from fbprophet import Prophet
for i in range(1,2):    
    df = pd.read_excel('pacifier_3.xlsx',header=0,sheet_name='Sheet'+str(i))
    # df['y'] = np.log(df['y'])
    m = Prophet()
    # m = Prophet(growth='logistic')
    m.fit(df)
    # Python
    future = m.make_future_dataframe(periods=365)
    # Python
    forecast = m.predict(future)
    forecast.to_excel('pacifier'+str(i)+'.xlsx')
    m.plot(forecast)
    m.plot_components(forecast).show()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -68.6756
# Iteration  1. Log joint probability =    24.3927. Improved by 93.0684.
# Iteration  2. Log joint probability =    73.9449. Improved by 49.5521.
# Iteration  3. Log joint probability =    87.5975. Improved by 13.6526.
# Iteration  4. Log joint probability =    88.3413. Improved by 0.743808.
# Iteration  5. Log joint probability =    88.6219. Improved by 0.280566.
# Iteration  6. Log joint probability =    88.6371. Improved by 0.0152465.
# Iteration  7. Log joint probability =    88.6457. Improved by 0.00851726.
# Iteration  8. Log joint probability =    88.6682. Improved by 0.0225842.
# Iteration  9. Log joint probability =    88.6791. Improved by 0.0108347.
# Iteration 10. Log joint probability =    88.6791. Improved by 2.38376e-05.
# Iteration 11. Log joint probability =    88.6797. Improved by 0.000610968.
# Iteration 12. Log joint probability =    88.6861. Improved by 0.00642442.
# Iteration 13. Log joint probability =    88.6888. Improved by 0.00265374.
# Iteration 14. Log joint probability =    88.6897. Improved by 0.000939134.
# Iteration 15. Log joint probability =    88.6902. Improved by 0.000470534.
# Iteration 16. Log joint probability =    88.6902. Improved by 6.9606e-06.
# Iteration 17. Log joint probability =    88.6905. Improved by 0.000336715.
# Iteration 18. Log joint probability =     88.691. Improved by 0.000449709.
# Iteration 19. Log joint probability =    88.6914. Improved by 0.000395884.
# Iteration 20. Log joint probability =    88.6916. Improved by 0.000187692.
# Iteration 21. Log joint probability =    88.6916. Improved by 6.08564e-05.
# Iteration 22. Log joint probability =    88.6916. Improved by 3.75776e-06.
# Iteration 23. Log joint probability =    88.6917. Improved by 1.66025e-05.
# Iteration 24. Log joint probability =    88.6918. Improved by 0.000185802.
# Iteration 25. Log joint probability =    88.6919. Improved by 9.04753e-05.
# Iteration 26. Log joint probability =    88.6919. Improved by 8.01415e-06.
# Iteration 27. Log joint probability =     88.692. Improved by 7.26869e-06.
# Iteration 28. Log joint probability =     88.692. Improved by 3.55008e-05.
# Iteration 29. Log joint probability =     88.692. Improved by 1.59071e-05.
# Iteration 30. Log joint probability =     88.692. Improved by 1.94296e-05.
# Iteration 31. Log joint probability =     88.692. Improved by 1.18977e-06.
# Iteration 32. Log joint probability =     88.692. Improved by 9.8779e-06.
# Iteration 33. Log joint probability =     88.692. Improved by 1.10067e-06.
# Iteration 34. Log joint probability =     88.692. Improved by 1.72682e-06.
# Iteration 35. Log joint probability =     88.692. Improved by 4.75185e-06.
# Iteration 36. Log joint probability =     88.692. Improved by 6.25782e-08.
# Iteration 37. Log joint probability =     88.692. Improved by 2.39011e-06.
# Iteration 38. Log joint probability =     88.692. Improved by 6.88996e-07.
# Iteration 39. Log joint probability =     88.692. Improved by 1.66628e-06.
# Iteration 40. Log joint probability =     88.692. Improved by 3.49378e-07.
# Iteration 41. Log joint probability =     88.692. Improved by 2.35387e-07.
# Iteration 42. Log joint probability =    88.6921. Improved by 3.15367e-07.
# Iteration 43. Log joint probability =    88.6921. Improved by 7.81249e-09.
