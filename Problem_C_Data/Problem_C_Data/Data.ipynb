# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
hair_dryer = pd.read_csv('hair_dryer.tsv',header=0,sep='\t')
microwave = pd.read_csv('microwave.tsv',sep='\t',header=0)
pacifier = pd.read_csv('pacifier.tsv',sep='\t',header=0)

# %%
sns.heatmap(pacifier.isnull(),cmap="YlGnBu")
plt.show()

# %%
hair_dryer.dropna(inplace=True)
microwave.dropna(inplace=True)
pacifier.dropna(inplace=True)
